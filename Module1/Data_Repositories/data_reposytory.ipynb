# %% [markdown]
# #### Description:
#
# ##### Web URL source: <https://www.kaggle.com/datasets/stefanoleone992/mutual-funds-and-etfs>
#
# This dataset includes the financial information collected from Yahoo Finance and includes all U.S. Mutual Funds and along with their historical prices. The file contains 23,783 Mutual Funds and 2,310 ETFs with:
# General fund aspects (e.g. total_net_assets, fund family, inception date, etc.)
# Portfolio indicators (e.g. cash, stocks, bonds, sectors, etc.)
# Historical yearly and quarterly returns (e.g. year_to_date, 1-year, 3-years, etc.)
# Financial ratios (price/earning, Treynor and Sharpe ratios, alpha, and beta)
# ESG scores
#
# #### Use Cases:
# Private investor and Corporate institutions
# Trading Strategies: Design and validate trading techniques based on mutual funds and ETFs.
# Risk Management: Use the data for hedging decisions and risk management for businesses.
#
# #### Source:
# url = https://storage.googleapis.com/kaggle-data-sets/55721/2915265/bundle/archive.zip

# %%
#Data Frame of Mutual Funds and ETFs
import pandas as pd

data_funds = pd.read_csv('data/mutual_funds_data.csv')
data_funds
# Out:
#       fund_symbol  quote_type region                  fund_short_name  \
# 0           AAAAX  MutualFund     US  DWS RREEF Real Assets Fund - Cl
# 1           AAAEX  MutualFund     US  AllianzGI Health Sciences Fund
# 2           AAAFX  MutualFund     US                              NaN
# 3           AAAGX  MutualFund     US  Thrivent Large Cap Growth Fund
# 4           AAAHX  MutualFund     US                              NaN
# ...           ...         ...    ...                              ...
# 23778       ZVNIX  MutualFund     US  Fidelity Advisor Small Cap Valu
# 23779       VHYAX  MutualFund     US  Capital World Bond Fund - Class
# 23780       VIAAX  MutualFund     US  Capital World Growth and Income
# 23781       VIHAX  MutualFund     US      Templeton China World Cl R6
# 23782       TSWHX  MutualFund     US      Fidelity Select Industrials
#
#                                           fund_long_name currency  \
# ...

# %%
# Data Frame size
data_funds.shape
# Out:
# (23783, 298)

# %%
# Data Frame Description
data_funds.describe()
# Out:
#        initial_investment  subsequent_investment  total_net_assets  \
# count        1.648500e+04            8943.000000      2.374900e+04
# mean         5.179181e+06            1015.925752      4.924192e+09
# std          9.253584e+07           11023.969484      2.109765e+10
# min          1.000000e+01               1.000000      1.000000e+01
# 25%          1.000000e+03              50.000000      1.445834e+08
# 50%          2.500000e+03              50.000000      6.443283e+08
# 75%          5.000000e+05             100.000000      2.453409e+09
# max          5.000000e+09          500000.000000      7.534100e+11
#
#        year_to_date_return  day50_moving_average  day200_moving_average  \
# count         23382.000000          23782.000000           23782.000000
# mean              0.093485             23.638731              23.084989
# std               0.082276             33.126315              31.552946
# min              -0.522800              1.279000               1.363000
# ...

# %% [markdown]
# #### Description:
#
# ##### Web URL source: <https://www.kaggle.com/datasets/jesusgraterol/bitcoin-blockchain-dataset>
#
# A blockchain is a distributed ledger with growing lists of records (blocks) that are securely linked together via cryptographic hashes. Each block contains a cryptographic hash of the previous block, a timestamp, and transaction data (generally represented as a Merkle tree, where data nodes are represented by leaves)
#
# #### Use Cases:
# Individual researches and developers to be able to analyze the blockchain deeply or even train machine learning models in just a few minutes, instead of several hours/days
#
# #### Source:
# url = https://storage.googleapis.com/kaggle-data-sets/3554939/6359065/bundle/archive.zip

# %%
# Data Frame of Bitcoin cryptocurrency
df_bit = pd.read_csv('data/bitcoin_hist_data.csv')
df_bit
# Out:
#         height      timestamp     size  tx_count    difficulty  \
# 0            1  1231469665000      215         1  1.000000e+00
# 1            2  1231469744000      215         1  1.000000e+00
# 2            3  1231470173000      215         1  1.000000e+00
# 3            4  1231470988000      215         1  1.000000e+00
# 4            5  1231471428000      215         1  1.000000e+00
# ...        ...            ...      ...       ...           ...
# 804663  804664  1692882889000  1668438      2761  5.562144e+13
# 804664  804665  1692883478000  1393602      2977  5.562144e+13
# 804665  804666  1692883741000  1972901      5807  5.562144e+13
# 804666  804667  1692885144000  1536390      3794  5.562144e+13
# 804667  804668  1692885738000  1431158      2354  5.562144e+13
#
#         median_fee_rate  avg_fee_rate  total_fees  fee_range_min  \
# 0              0.000000             0           0       0.000000
# 1              0.000000             0           0       0.000000
# ...

# %%
# Data Frame size
df_bit.shape
# Out:
# (804668, 13)

# %%
# Data Frame Description
df_bit.describe()
# Out:
#               height     timestamp          size       tx_count    difficulty  \
# count  804668.000000  8.046680e+05  8.046680e+05  804668.000000  8.046680e+05
# mean   402334.500000  1.461348e+12  6.288598e+05    1098.575234  7.449962e+12
# std    232287.787543  1.305817e+11  5.998891e+05    1106.430154  1.243851e+13
# min         1.000000  1.231470e+12  1.760000e+02       1.000000  1.000000e+00
# 25%    201167.750000  1.348973e+12  3.333550e+04      68.000000  2.864141e+06
# 50%    402334.500000  1.457787e+12  4.397995e+05     667.000000  1.634917e+11
# 75%    603501.250000  1.573596e+12  1.140764e+06    2079.000000  1.294859e+13
# max    804668.000000  1.692886e+12  3.978938e+06   12239.000000  5.562144e+13
#
#        median_fee_rate  avg_fee_rate    total_fees  fee_range_min  \
# count     8.046680e+05  8.046680e+05  8.046680e+05  804668.000000
# mean      5.500943e+01  9.334386e+01  3.348021e+07       9.376817
# std       1.204936e+03  1.885444e+03  9.181505e+07     147.811305
# ...

# %% [markdown]
# #### Description:
#
# #### Web URL source: <https://www.kaggle.com/code/shubhamptrivedi/sentiment-analysis-for-dow-jones-djia-stock/input>
#
# In this case I will use two data sets market data and world news data, with possibility analysing the impact of the news to the stock market.
# The Dow Jones Industrial Average, Dow Jones, or simply the Dow, is a stock market index of 30 prominent companies listed on stock exchanges in the United States. The DJIA is one of the oldest and most commonly followed equity index. Also includes another set of data, which includes world news, that had one of biggest impacts on the stock markets for the chosen period.
#
# #### Use Cases:
# Trend Analysis: Examine patterns and price movements to predict stock market index behaviors.
# Academic Research: Study the historical behavior and impact of global events on stock prices.
# Trading Strategies: Design and validate trading techniques based on stock market index.
# Risk Management: Use the data for hedging decisions and risk management for businesses involved in stock market
#
# #### Source
# url = https://storage.googleapis.com/kaggle-data-sets/129/792900/bundle/archive.zip

# %%
# Data Frame of Down Jones Industrial Average 
djia_data = pd.read_csv('data/djia_data.csv')
djia_data
# Out:
#             Date          Open          High           Low         Close  \
# 0     2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
# 1     2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2     2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 3     2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 4     2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
# ...          ...           ...           ...           ...           ...
# 1984  2008-08-14  11532.070312  11718.280273  11450.889648  11615.929688
# 1985  2008-08-13  11632.809570  11633.780273  11453.339844  11532.959961
# 1986  2008-08-12  11781.700195  11782.349609  11601.519531  11642.469727
# 1987  2008-08-11  11729.669922  11867.110352  11675.530273  11782.349609
# 1988  2008-08-08  11432.089844  11759.959961  11388.040039  11734.320312
#
#          Volume     Adj Close
# 0      82160000  17949.369141
# ...

# %%
# Data Frame size
djia_data.shape
# Out:
# (1989, 7)

# %%
# Data Frame Description
djia_data.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   1989.000000   1989.000000   1989.000000   1989.000000  1.989000e+03
# mean   13459.116048  13541.303173  13372.931728  13463.032255  1.628110e+08
# std     3143.281634   3136.271725   3150.420934   3144.006996  9.392343e+07
# min     6547.009766   6709.609863   6469.950195   6547.049805  8.410000e+06
# 25%    10907.339844  11000.980469  10824.759766  10913.379883  1.000000e+08
# 50%    13022.049805  13088.110352  12953.129883  13025.580078  1.351700e+08
# 75%    16477.699219  16550.070312  16392.769531  16478.410156  1.926000e+08
# max    18315.060547  18351.359375  18272.560547  18312.390625  6.749200e+08
#
#           Adj Close
# count   1989.000000
# mean   13463.032255
# std     3144.006996
# min     6547.049805
# 25%    10913.379883
# 50%    13025.580078
# 75%    16478.410156
# max    18312.390625

# %%
djia_data.plot.hist(y=['Volume'])
# Out:
# <Axes: ylabel='Frequency'>

# %%
djia_data.plot.line(x='Date', y=['Volume'], figsize=(10, 6), grid=True)
# Out:
# <Axes: xlabel='Date'>

# %%
djia_data.plot.hist(y='Adj Close')
# Out:
# <Axes: ylabel='Frequency'>

# %%
djia_data.plot.line(x='Date', y=['Adj Close'], figsize=(10, 6), grid=True)
# Out:
# <Axes: xlabel='Date'>

# %%
djia_data.plot.scatter(x='Volume', y='Adj Close', figsize=(15, 10), grid=True)
# Out:
# <Axes: xlabel='Volume', ylabel='Adj Close'>

# %%
djia_data.plot.hist(y=['Volume', 'Adj Close'])
# Out:
# <Axes: ylabel='Frequency'>

# %%
djia_data.Date = pd.to_datetime(djia_data['Date']).dt.date
djia_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1989 non-null   object
#  1   Open       1989 non-null   float64
#  2   High       1989 non-null   float64
#  3   Low        1989 non-null   float64
#  4   Close      1989 non-null   float64
#  5   Volume     1989 non-null   int64
#  6   Adj Close  1989 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 108.9+ KB

# %%
# start_date = pd.to_datetime('2014-10-02 00:00:01')
# end_date = pd.to_datetime('2014-11-02 00:00:01')
# djia_data.loc[(djia_data['TIME'] > start_date) & (djia_data['TIME'] < end_date)]
# djia_data.loc[(djia_data['TIME'].dt.date > start_date.date()) & (djia_data['TIME'].dt.date< end_date,date())]
start_date = pd.to_datetime('2009-01-01').date()
end_date = pd.to_datetime('2009-06-15').date()
djia_data_vol = djia_data.loc[(djia_data['Date'] > start_date) & (djia_data['Date'] < end_date),]
djia_data_vol
# Out:
#             Date         Open         High          Low        Close  \
# 1776  2009-06-12  8770.009766  8805.530273  8716.730469  8799.259766
# 1777  2009-06-11  8736.230469  8877.929688  8736.230469  8770.919922
# 1778  2009-06-10  8763.660156  8834.929688  8639.950195  8739.019531
# 1779  2009-06-09  8764.830078  8803.259766  8725.120117  8763.059570
# 1780  2009-06-08  8759.349609  8823.969727  8633.070312  8764.490234
# ...          ...          ...          ...          ...          ...
# 1883  2009-01-08  8769.940430  8770.019531  8651.190430  8742.459961
# 1884  2009-01-07  8996.940430  8996.940430  8719.919922  8769.700195
# 1885  2009-01-06  8954.570312  9088.059570  8940.950195  9015.099609
# 1886  2009-01-05  9027.129883  9034.370117  8892.360352  8952.889648
# 1887  2009-01-02  8772.250000  9065.280273  8760.780273  9034.690430
#
#          Volume    Adj Close
# 1776  164020000  8799.259766
# 1777  249900000  8770.919922
# 1778  219920000  8739.019531
# ...

# %%
djia_data_vol.plot.line(x='Date', y=['Adj Close'], figsize=(15, 10), grid=True)
# Out:
# <Axes: xlabel='Date'>

# %%
djia_data_vol.plot.line(x='Date', y=['Volume'], figsize=(15, 10), grid=True)
# Out:
# <Axes: xlabel='Date'>

# %%
djia_data.plot.scatter(x='Adj Close', y='Volume', figsize=(15, 10), grid=True)
# Out:
# <Axes: xlabel='Adj Close', ylabel='Volume'>

# %%
djia_data.plot.line(x='Date', y='Adj Close', figsize=(15, 10), grid=True)
# Out:
# <Axes: xlabel='Date'>

# %%
# Data Frame of World news for DJIA
news_data = pd.read_csv('data/djia_news.csv')
news_data
# Out:
#             Date  Label                                               Top1  \
# 0     2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1     2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2     2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3     2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 4     2008-08-14      1  b'All the experts admit that we should legalis...
# ...          ...    ...                                                ...
# 1984  2016-06-27      0  Barclays and RBS shares suspended from trading...
# 1985  2016-06-28      1  2,500 Scientists To Australia: If You Want To ...
# 1986  2016-06-29      1                   Explosion At Airport In Istanbul
# 1987  2016-06-30      1  Jamaica proposes marijuana dispensers for tour...
# 1988  2016-07-01      1  A 117-year-old woman in Mexico City finally re...
#
#                                                    Top2  \
# ...

# %%
# Data Frame size
news_data.shape
# Out:
# (1989, 27)

# %%
# Data Frame Description
news_data.describe()
# Out:
#              Label
# count  1989.000000
# mean      0.535445
# std       0.498867
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
#news_data.loc[news_data['Date'] == str(),]
str(start_date)
news_data.loc[news_data['Date'] == '2009-03-06',].T
# Out:
#                                                      144
# Date                                          2009-03-06
# Label                                                  1
# Top1   b'The Economist: "... the war on drugs has bee...
# Top2   b"SAS commander: Afghan operation is 'worthles...
# Top3   b"Morgan Tsvangirai's wife 'killed by US aid t...
# Top4   b'Fighting in the Field: Monsanto\'s Uphill Ba...
# Top5   b'Human rights investigators say Israeli force...
# Top6   b'Israeli Soldiers Leave their Shit in Gaza Fr...
# Top7   b'This American Life does the banking crisis. ...
# Top8         b'Top 10 Endangered Languages in the World'
# Top9   b'Kenyan human rights activists killed after a...
# Top10               b"NY 'mafia cops' get life in jail "
# Top11  b'Outrage in France over plight of boy locked ...
# Top12  b"Fatal Tsvangirai crash 'was not accident', s...
# Top13  b'Burning Conscience: Israeli soldiers speak o...
# ...

# %%
news_data.loc[news_data['Date'] == '2009-03-09',].T
# Out:
#                                                      145
# Date                                          2009-03-09
# Label                                                  0
# Top1   b'Kim Jong-Il wins re-election with 99.9% of t...
# Top2   b'The Norton Antivirus cover-up: A mysterious ...
# Top3   b"Indias New Face:  Meet the pro-business anti...
# Top4   b"Dalai Lama warns Tibetans are 'near extincti...
# Top5   b'Official Website of North Korea: "Is North K...
# Top6   b'Israel at it again, this time pillaging reso...
# Top7   b'Pirate Party Politician Fired for His Politi...
# Top8   b" Dalai Lama: China makes life 'hell on Earth...
# Top9   b'New Zealand\'s RIAA tries to justifiy new "G...
# Top10  b'"Under President Obamas plan, up to 50,000 U...
# Top11  b'Heroin use is killing Russia, most of heroin...
# Top12  b'Chinese attempt to instigate collision with ...
# Top13  b'Mideast: Home Demolitions Threaten Peace Talks'
# ...

# %%
news_data.loc[news_data['Date'] == '2009-03-10',].T
# Out:
#                                                      146
# Date                                          2009-03-10
# Label                                                  1
# Top1   b"UK would like to force the EU to end net neu...
# Top2   b'10 dead after teen shooting rampage at Germa...
# Top3   b'Bolivia expels second US diplomat for having...
# Top4      b'Military to use new gel that stops bullets '
# Top5   b'The global drug charade: Flying in the face ...
# Top6   b'" Just this past week in the East Jerusalem ...
# Top7   b'The Economist: The Only Way To Stop The Fail...
# Top8   b'Madoff Charged With 11 Felonies, Faces 150 Y...
# Top9   b"Tariq Aziz, for many years the public face o...
# Top10  b"Secret message in Abraham Lincoln's watch re...
# Top11  b'Al-Jazeeras coverage of dictators is more ho...
# Top12               b'France ends four-decade NATO rift'
# Top13  b'BBC NEWS | World | Europe | France ends four...
# ...

# %%
djia_data.loc[djia_data.Date == pd.to_datetime('2009-03-09').date(),['Adj Close','Volume']].plot.bar()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=3, ncols=2)
djia_data.plot.line(ax=axes[0,0], x='Date', y=['Volume'], figsize=(10, 6), grid=True)
djia_data.plot.line(ax=axes[0,1], x='Date', y=['Adj Close'], figsize=(10, 6), grid=True)
djia_data.plot.hist(ax=axes[1,0], y='Volume')
djia_data.plot.hist(ax=axes[1,1], y='Adj Close')
djia_data.plot.scatter(ax=axes[2,0], x='Volume', y='Adj Close', figsize=(15, 10), grid=True)
djia_data_vol.plot.line(ax=axes[2,1], x='Date', y=['Adj Close'], figsize=(15, 10), grid=True)
# Out:
# <Axes: xlabel='Date'>

# %%
news_data.loc[news_data['Date'] == '2009-03-06',].T
# Out:
#                                                      144
# Date                                          2009-03-06
# Label                                                  1
# Top1   b'The Economist: "... the war on drugs has bee...
# Top2   b"SAS commander: Afghan operation is 'worthles...
# Top3   b"Morgan Tsvangirai's wife 'killed by US aid t...
# Top4   b'Fighting in the Field: Monsanto\'s Uphill Ba...
# Top5   b'Human rights investigators say Israeli force...
# Top6   b'Israeli Soldiers Leave their Shit in Gaza Fr...
# Top7   b'This American Life does the banking crisis. ...
# Top8         b'Top 10 Endangered Languages in the World'
# Top9   b'Kenyan human rights activists killed after a...
# Top10               b"NY 'mafia cops' get life in jail "
# Top11  b'Outrage in France over plight of boy locked ...
# Top12  b"Fatal Tsvangirai crash 'was not accident', s...
# Top13  b'Burning Conscience: Israeli soldiers speak o...
# ...
