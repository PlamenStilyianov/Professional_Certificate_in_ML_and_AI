# %% [markdown]
# # <center>Try-it 1.1

# %% [markdown]
# ### In this exercise, generate some basic charts using Pandas.

# %%
# import data from pandas
import pandas as pd
import os

#Make directory called plots
os.makedirs("plots", exist_ok=True)

#create the DataFrame utilizing Pandas 
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 

#generate all info for this dataset
data.info()

#Remove the last line of NAN
data = data.iloc[:-1 , :]

#Ignore any warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 452           Kentucky  2239800.0
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
#
# [457 rows x 9 columns]

# %% [markdown]
# ###  Part One: In this exercise, generate a basic histogram.

# %%
#Please generate a basic histogram and save the histogram as a png file
# Hint: use pandas histogram function.
img = data.plot(kind='hist',y=['Number','Age','Weight','Salary'])
img.figure.savefig('plots/demo-hist.png')

# ax = s.plot.hist()
# ax.figure.savefig('demo-file.pdf')

# %% [markdown]
# ###  Part Two: In this exercise, generate a basic scatter plot.

# %%
#Please generate a basic scatter plot utilizing Age as the x axis and Salary as the y axis
# Hint: use pandas scatter function to generate the chart.

scat = data.plot.scatter(x='Age',y='Salary')
scat.figure.savefig('plots/demo-scatter.png')
print(scat)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ###  Part Three: In this exercise, generate a basic lineplot.

# %%
# Please generate a basic line plot by name as the x axis and salary as the y axis 
#for the "Golden State Warriors" using the nba data set. 
#Note a new dataframe called teamdata has been created for you that will be used during the rest of this 



teamdata = data.filter(items=['Team', 'Name', 'Salary'])
teamdata = teamdata.loc[data.Team == 'Golden State Warriors', 'Name':'Salary']

# REDANDANT LINE OF CODE
# If the data frame index is set to the First series or column named 'Name', 
# the pd.DataFrame.plot.line will throws an error as KeyError: "None of ['Name'] are in the columns"
#teamdata = teamdata.set_index('Name',inplace=True)
#teamdata.set_index('Name', inplace=True)
teamdata.set_index('Name')

print(teamdata)

lines = teamdata.plot.line(x='Name', y='Salary')
lines.figure.savefig('plots/demo-line.png')

# ANSWER CHECK
print(lines)
# Out:
#                     Name      Salary
# 76       Leandro Barbosa   2500000.0
# 77       Harrison Barnes   3873398.0
# 78          Andrew Bogut  13800000.0
# 79             Ian Clark    947276.0
# 80         Stephen Curry  11370786.0
# 81          Festus Ezeli   2008748.0
# 82        Draymond Green  14260870.0
# 83        Andre Iguodala  11710456.0
# 84      Shaun Livingston   5543725.0
# 85          Kevon Looney   1131960.0
# 86  James Michael McAdoo    845059.0
# 87          Brandon Rush   1270964.0
# 88     Marreese Speights   3815000.0
# 89         Klay Thompson  15501000.0
# 90      Anderson Varejao    289755.0
# Axes(0.125,0.11;0.775x0.77)

# %%
teamdata = data.filter(items=['Team', 'Name', 'Salary'])
teamdata = teamdata.loc[data.Team == 'Golden State Warriors', 'Name':'Salary']
teamdata.set_index('Name', inplace=True)

teamdata
# Out:
#                           Salary
# Name
# Leandro Barbosa        2500000.0
# Harrison Barnes        3873398.0
# Andrew Bogut          13800000.0
# Ian Clark               947276.0
# Stephen Curry         11370786.0
# Festus Ezeli           2008748.0
# Draymond Green        14260870.0
# Andre Iguodala        11710456.0
# Shaun Livingston       5543725.0
# Kevon Looney           1131960.0
# James Michael McAdoo    845059.0
# Brandon Rush           1270964.0
# Marreese Speights      3815000.0
# Klay Thompson         15501000.0
# Anderson Varejao        289755.0

# %%
teamdata.reset_index().plot.line(x='Name', y='Salary')
# Out:
# <Axes: xlabel='Name'>

# %% [markdown]
# ###  Part Four: In this exercise, generate a basic bar chart.

# %%
# Please generate a basic bar plot by name as the x axis and salary as the y axis of the teamdata dataframe.
 

bar = teamdata.reset_index().plot.bar(x='Name',y='Salary',)
bar.figure.savefig('plots/demo-bar.png')



print(bar)
# Out:
# Axes(0.125,0.11;0.775x0.77)
